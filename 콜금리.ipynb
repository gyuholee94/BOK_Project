# %% [markdown]
# <a href="https://colab.research.google.com/github/gyuholee94/BOK_Project/blob/gyuho%2Ftest/%EC%BD%9C%EA%B8%88%EB%A6%AC.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# no_page = 693
# dates =[]
# call_rates = []
# index = ['날짜', '콜금리']
# for page in range(no_page):

#   url = 'https://finance.naver.com/marketindex/interestDailyQuote.nhn'
#   query = {
#       'marketindexCd' : 'IRR_CALL',
#       'page' : page+1
#   }
#   resp = requests.get(url, query)
#   soup = BeautifulSoup(resp.content, 'lxml')

#   date = soup.select('td.date')
#   call_rate = soup.select('td.num')
#   for i in range(len(date)):
#     if i%4 == 0:
#       dates.append(date[i].text)
#     else:
#       call_rates.append(call_rate[i].text)

# Call_rates = pd.DataFrame([dates, call_rates], index=index)
# Call_rates.to_csv('Call_rates.csv')

# %%
# url = 'https://finance.naver.com/marketindex/interestDailyQuote.nhn'
# query = {
#     'marketindexCd' : 'IRR_CALL',
#     'page' : 1
# }
# resp = requests.get(url, query)
# soup = BeautifulSoup(resp.content, 'lxml')

# date = soup.select('td.date')
# call_rate = soup.select('td.num')

# print(call_rate[3])
# Out:
# <td class="num">0.46</td>

# %%
# dates = []
# call_rates = []

# for page in range(3):

#   url = 'https://finance.naver.com/marketindex/interestDailyQuote.nhn'
#   query = {
#       'marketindexCd' : 'IRR_CALL',
#       'page' : page+1
#   }
#   resp = requests.get(url, query)
#   soup = BeautifulSoup(resp.content, 'lxml')

#   date = soup.select('td.date')
#   call_rate = soup.select('td.num')
#   for i in range(len(date)):
#     dates.append(date[i].text.strip())
#     call_rates.append(call_rate[i*3-3].text.strip())
# print(len(dates), len(call_rates))
# Out:
# 21 21

# %%
from bs4 import BeautifulSoup
import pandas as pd
import tqdm
import requests

no_page = 693
dates =[]
call_rates = []
index = ['date', 'callrate']

for page in range(no_page):

  url = 'https://finance.naver.com/marketindex/interestDailyQuote.nhn'
  query = {
      'marketindexCd' : 'IRR_CALL',
      'page' : page+1
  }
  resp = requests.get(url, query)
  soup = BeautifulSoup(resp.content, 'lxml')

  date = soup.select('td.date')
  call_rate = soup.select('td.num')
  for i in range(len(date)):
    dates.append(date[i].text.strip())
    call_rates.append(call_rate[i*3-3].text.strip())
Call_rates = pd.DataFrame([dates, call_rates], index=index)
Call_rates = Call_rates.T
Call_rates.to_csv('Call_rates.csv')

# %%
Call_rates
# Out:
#             date callrate
# 0     2020.07.23     0.47
# 1     2020.07.22     0.46
# 2     2020.07.21     0.45
# 3     2020.07.20     0.46
# 4     2020.07.17     0.44
# ...          ...      ...
# 4844  2001.01.09     5.28
# 4845  2001.01.08     5.30
# 4846  2001.01.05     5.32
# 4847  2001.01.04     5.34
# 4848  2001.01.03     5.30
#
# [4849 rows x 2 columns]

# %%
import pandas

dt_index = pandas.date_range(start='20050401', end='20171231')

dt_list = dt_index.strftime("%Y.%m.%d").tolist()
datels = []
for i in dt_list:
    datels.append(i)
datels
# Out:
# ['2005.04.01',
#  '2005.04.02',
#  '2005.04.03',
#  '2005.04.04',
#  '2005.04.05',
#  '2005.04.06',
#  '2005.04.07',
#  '2005.04.08',
#  '2005.04.09',
#  '2005.04.10',
#  '2005.04.11',
#  '2005.04.12',
#  '2005.04.13',
#  '2005.04.14',
#  '2005.04.15',
#  '2005.04.16',
#  '2005.04.17',
#  '2005.04.18',
#  '2005.04.19',
#  '2005.04.20',
#  '2005.04.21',
#  '2005.04.22',
#  '2005.04.23',
#  '2005.04.24',
#  '2005.04.25',
#  '2005.04.26',
#  '2005.04.27',
#  '2005.04.28',
#  '2005.04.29',
#  '2005.04.30',
#  '2005.05.01',
#  '2005.05.02',
#  '2005.05.03',
#  '2005.05.04',
#  '2005.05.05',
#  '2005.05.06',
#  '2005.05.07',
#  '2005.05.08',
#  '2005.05.09',
#  '2005.05.10',
#  '2005.05.11',
#  '2005.05.12',
#  '2005.05.13',
#  '2005.05.14',
#  '2005.05.15',
#  '2005.05.16',
#  '2005.05.17',
#  '2005.05.18',
#  '2005.05.19',
#  '2005.05.20',
#  '2005.05.21',
#  '2005.05.22',
#  '2005.05.23',
#  '2005.05.24',
#  '2005.05.25',
#  '2005.05.26',
#  '2005.05.27',
#  '2005.05.28',
#  '2005.05.29',
#  '2005.05.30',
#  '2005.05.31',
#  '2005.06.01',
#  '2005.06.02',
#  '2005.06.03',
#  '2005.06.04',
#  '2005.06.05',
#  '2005.06.06',
#  '2005.06.07',
#  '2005.06.08',
#  '2005.06.09',
#  '2005.06.10',
#  '2005.06.11',
#  '2005.06.12',
#  '2005.06.13',
#  '2005.06.14',
#  '2005.06.15',
#  '2005.06.16',
#  '2005.06.17',
#  '2005.06.18',
#  '2005.06.19',
#  '2005.06.20',
#  '2005.06.21',
#  '2005.06.22',
#  '2005.06.23',
#  '2005.06.24',
#  '2005.06.25',
#  '2005.06.26',
#  '2005.06.27',
#  '2005.06.28',
#  '2005.06.29',
#  '2005.06.30',
#  '2005.07.01',
#  '2005.07.02',
#  '2005.07.03',
#  '2005.07.04',
#  '2005.07.05',
#  '2005.07.06',
#  '2005.07.07',
#  '2005.07.08',
#  '2005.07.09',
#  '2005.07.10',
#  '2005.07.11',
#  '2005.07.12',
#  '2005.07.13',
#  '2005.07.14',
#  '2005.07.15',
#  '2005.07.16',
#  '2005.07.17',
#  '2005.07.18',
#  '2005.07.19',
#  '2005.07.20',
#  '2005.07.21',
#  '2005.07.22',
#  '2005.07.23',
#  '2005.07.24',
#  '2005.07.25',
#  '2005.07.26',
#  '2005.07.27',
#  '2005.07.28',
#  '2005.07.29',
#  '2005.07.30',
#  '2005.07.31',
#  '2005.08.01',
#  '2005.08.02',
#  '2005.08.03',
#  '2005.08.04',
#  '2005.08.05',
#  '2005.08.06',
#  '2005.08.07',
#  '2005.08.08',
#  '2005.08.09',
#  '2005.08.10',
#  '2005.08.11',
#  '2005.08.12',
#  '2005.08.13',
#  '2005.08.14',
#  '2005.08.15',
#  '2005.08.16',
#  '2005.08.17',
#  '2005.08.18',
#  '2005.08.19',
#  '2005.08.20',
#  '2005.08.21',
#  '2005.08.22',
#  '2005.08.23',
#  '2005.08.24',
#  '2005.08.25',
#  '2005.08.26',
#  '2005.08.27',
#  '2005.08.28',
#  '2005.08.29',
#  '2005.08.30',
#  '2005.08.31',
#  '2005.09.01',
#  '2005.09.02',
#  '2005.09.03',
#  '2005.09.04',
#  '2005.09.05',
#  '2005.09.06',
#  '2005.09.07',
#  '2005.09.08',
#  '2005.09.09',
#  '2005.09.10',
#  '2005.09.11',
#  '2005.09.12',
#  '2005.09.13',
#  '2005.09.14',
#  '2005.09.15',
#  '2005.09.16',
#  '2005.09.17',
#  '2005.09.18',
#  '2005.09.19',
#  '2005.09.20',
#  '2005.09.21',
#  '2005.09.22',
#  '2005.09.23',
#  '2005.09.24',
#  '2005.09.25',
#  '2005.09.26',
#  '2005.09.27',
#  '2005.09.28',
#  '2005.09.29',
#  '2005.09.30',
#  '2005.10.01',
#  '2005.10.02',
#  '2005.10.03',
#  '2005.10.04',
#  '2005.10.05',
#  '2005.10.06',
#  '2005.10.07',
#  '2005.10.08',
#  '2005.10.09',
#  '2005.10.10',
#  '2005.10.11',
#  '2005.10.12',
#  '2005.10.13',
#  '2005.10.14',
#  '2005.10.15',
#  '2005.10.16',
#  '2005.10.17',
#  '2005.10.18',
#  '2005.10.19',
#  '2005.10.20',
#  '2005.10.21',
#  '2005.10.22',
#  '2005.10.23',
#  '2005.10.24',
#  '2005.10.25',
#  '2005.10.26',
#  '2005.10.27',
#  '2005.10.28',
#  '2005.10.29',
#  '2005.10.30',
#  '2005.10.31',
#  '2005.11.01',
#  '2005.11.02',
#  '2005.11.03',
#  '2005.11.04',
#  '2005.11.05',
#  '2005.11.06',
#  '2005.11.07',
#  '2005.11.08',
#  '2005.11.09',
#  '2005.11.10',
#  '2005.11.11',
#  '2005.11.12',
#  '2005.11.13',
#  '2005.11.14',
#  '2005.11.15',
#  '2005.11.16',
#  '2005.11.17',
#  '2005.11.18',
#  '2005.11.19',
#  '2005.11.20',
#  '2005.11.21',
#  '2005.11.22',
#  '2005.11.23',
#  '2005.11.24',
#  '2005.11.25',
#  '2005.11.26',
#  '2005.11.27',
#  '2005.11.28',
#  '2005.11.29',
#  '2005.11.30',
#  '2005.12.01',
#  '2005.12.02',
#  '2005.12.03',
#  '2005.12.04',
#  '2005.12.05',
#  '2005.12.06',
#  '2005.12.07',
#  '2005.12.08',
#  '2005.12.09',
#  '2005.12.10',
#  '2005.12.11',
#  '2005.12.12',
#  '2005.12.13',
#  '2005.12.14',
#  '2005.12.15',
#  '2005.12.16',
#  '2005.12.17',
#  '2005.12.18',
#  '2005.12.19',
#  '2005.12.20',
#  '2005.12.21',
#  '2005.12.22',
#  '2005.12.23',
#  '2005.12.24',
#  '2005.12.25',
#  '2005.12.26',
#  '2005.12.27',
#  '2005.12.28',
#  '2005.12.29',
#  '2005.12.30',
#  '2005.12.31',
#  '2006.01.01',
#  '2006.01.02',
#  '2006.01.03',
#  '2006.01.04',
#  '2006.01.05',
#  '2006.01.06',
#  '2006.01.07',
#  '2006.01.08',
#  '2006.01.09',
#  '2006.01.10',
#  '2006.01.11',
#  '2006.01.12',
#  '2006.01.13',
#  '2006.01.14',
#  '2006.01.15',
#  '2006.01.16',
#  '2006.01.17',
#  '2006.01.18',
#  '2006.01.19',
#  '2006.01.20',
#  '2006.01.21',
#  '2006.01.22',
#  '2006.01.23',
#  '2006.01.24',
#  '2006.01.25',
#  '2006.01.26',
#  '2006.01.27',
#  '2006.01.28',
#  '2006.01.29',
#  '2006.01.30',
#  '2006.01.31',
#  '2006.02.01',
#  '2006.02.02',
#  '2006.02.03',
#  '2006.02.04',
#  '2006.02.05',
#  '2006.02.06',
#  '2006.02.07',
#  '2006.02.08',
#  '2006.02.09',
#  '2006.02.10',
#  '2006.02.11',
#  '2006.02.12',
#  '2006.02.13',
#  '2006.02.14',
#  '2006.02.15',
#  '2006.02.16',
#  '2006.02.17',
#  '2006.02.18',
#  '2006.02.19',
#  '2006.02.20',
#  '2006.02.21',
#  '2006.02.22',
#  '2006.02.23',
#  '2006.02.24',
#  '2006.02.25',
#  '2006.02.26',
#  '2006.02.27',
#  '2006.02.28',
#  '2006.03.01',
#  '2006.03.02',
#  '2006.03.03',
#  '2006.03.04',
#  '2006.03.05',
#  '2006.03.06',
#  '2006.03.07',
#  '2006.03.08',
#  '2006.03.09',
#  '2006.03.10',
#  '2006.03.11',
#  '2006.03.12',
#  '2006.03.13',
#  '2006.03.14',
#  '2006.03.15',
#  '2006.03.16',
#  '2006.03.17',
#  '2006.03.18',
#  '2006.03.19',
#  '2006.03.20',
#  '2006.03.21',
#  '2006.03.22',
#  '2006.03.23',
#  '2006.03.24',
#  '2006.03.25',
#  '2006.03.26',
#  '2006.03.27',
#  '2006.03.28',
#  '2006.03.29',
#  '2006.03.30',
#  '2006.03.31',
#  '2006.04.01',
#  '2006.04.02',
#  '2006.04.03',
#  '2006.04.04',
#  '2006.04.05',
#  '2006.04.06',
#  '2006.04.07',
#  '2006.04.08',
#  '2006.04.09',
#  '2006.04.10',
#  '2006.04.11',
#  '2006.04.12',
#  '2006.04.13',
#  '2006.04.14',
#  '2006.04.15',
#  '2006.04.16',
#  '2006.04.17',
#  '2006.04.18',
#  '2006.04.19',
#  '2006.04.20',
#  '2006.04.21',
#  '2006.04.22',
#  '2006.04.23',
#  '2006.04.24',
#  '2006.04.25',
#  '2006.04.26',
#  '2006.04.27',
#  '2006.04.28',
#  '2006.04.29',
#  '2006.04.30',
#  '2006.05.01',
#  '2006.05.02',
#  '2006.05.03',
#  '2006.05.04',
#  '2006.05.05',
#  '2006.05.06',
#  '2006.05.07',
#  '2006.05.08',
#  '2006.05.09',
#  '2006.05.10',
#  '2006.05.11',
#  '2006.05.12',
#  '2006.05.13',
#  '2006.05.14',
#  '2006.05.15',
#  '2006.05.16',
#  '2006.05.17',
#  '2006.05.18',
#  '2006.05.19',
#  '2006.05.20',
#  '2006.05.21',
#  '2006.05.22',
#  '2006.05.23',
#  '2006.05.24',
#  '2006.05.25',
#  '2006.05.26',
#  '2006.05.27',
#  '2006.05.28',
#  '2006.05.29',
#  '2006.05.30',
#  '2006.05.31',
#  '2006.06.01',
#  '2006.06.02',
#  '2006.06.03',
#  '2006.06.04',
#  '2006.06.05',
#  '2006.06.06',
#  '2006.06.07',
#  '2006.06.08',
#  '2006.06.09',
#  '2006.06.10',
#  '2006.06.11',
#  '2006.06.12',
#  '2006.06.13',
#  '2006.06.14',
#  '2006.06.15',
#  '2006.06.16',
#  '2006.06.17',
#  '2006.06.18',
#  '2006.06.19',
#  '2006.06.20',
#  '2006.06.21',
#  '2006.06.22',
#  '2006.06.23',
#  '2006.06.24',
#  '2006.06.25',
#  '2006.06.26',
#  '2006.06.27',
#  '2006.06.28',
#  '2006.06.29',
#  '2006.06.30',
#  '2006.07.01',
#  '2006.07.02',
#  '2006.07.03',
#  '2006.07.04',
#  '2006.07.05',
#  '2006.07.06',
#  '2006.07.07',
#  '2006.07.08',
#  '2006.07.09',
#  '2006.07.10',
#  '2006.07.11',
#  '2006.07.12',
#  '2006.07.13',
#  '2006.07.14',
#  '2006.07.15',
#  '2006.07.16',
#  '2006.07.17',
#  '2006.07.18',
#  '2006.07.19',
#  '2006.07.20',
#  '2006.07.21',
#  '2006.07.22',
#  '2006.07.23',
#  '2006.07.24',
#  '2006.07.25',
#  '2006.07.26',
#  '2006.07.27',
#  '2006.07.28',
#  '2006.07.29',
#  '2006.07.30',
#  '2006.07.31',
#  '2006.08.01',
#  '2006.08.02',
#  '2006.08.03',
#  '2006.08.04',
#  '2006.08.05',
#  '2006.08.06',
#  '2006.08.07',
#  '2006.08.08',
#  '2006.08.09',
#  '2006.08.10',
#  '2006.08.11',
#  '2006.08.12',
#  '2006.08.13',
#  '2006.08.14',
#  '2006.08.15',
#  '2006.08.16',
#  '2006.08.17',
#  '2006.08.18',
#  '2006.08.19',
#  '2006.08.20',
#  '2006.08.21',
#  '2006.08.22',
#  '2006.08.23',
#  '2006.08.24',
#  '2006.08.25',
#  '2006.08.26',
#  '2006.08.27',
#  '2006.08.28',
#  '2006.08.29',
#  '2006.08.30',
#  '2006.08.31',
#  '2006.09.01',
#  '2006.09.02',
#  '2006.09.03',
#  '2006.09.04',
#  '2006.09.05',
#  '2006.09.06',
#  '2006.09.07',
#  '2006.09.08',
#  '2006.09.09',
#  '2006.09.10',
#  '2006.09.11',
#  '2006.09.12',
#  '2006.09.13',
#  '2006.09.14',
#  '2006.09.15',
#  '2006.09.16',
#  '2006.09.17',
#  '2006.09.18',
#  '2006.09.19',
#  '2006.09.20',
#  '2006.09.21',
#  '2006.09.22',
#  '2006.09.23',
#  '2006.09.24',
#  '2006.09.25',
#  '2006.09.26',
#  '2006.09.27',
#  '2006.09.28',
#  '2006.09.29',
#  '2006.09.30',
#  '2006.10.01',
#  '2006.10.02',
#  '2006.10.03',
#  '2006.10.04',
#  '2006.10.05',
#  '2006.10.06',
#  '2006.10.07',
#  '2006.10.08',
#  '2006.10.09',
#  '2006.10.10',
#  '2006.10.11',
#  '2006.10.12',
#  '2006.10.13',
#  '2006.10.14',
#  '2006.10.15',
#  '2006.10.16',
#  '2006.10.17',
#  '2006.10.18',
#  '2006.10.19',
#  '2006.10.20',
#  '2006.10.21',
#  '2006.10.22',
#  '2006.10.23',
#  '2006.10.24',
#  '2006.10.25',
#  '2006.10.26',
#  '2006.10.27',
#  '2006.10.28',
#  '2006.10.29',
#  '2006.10.30',
#  '2006.10.31',
#  '2006.11.01',
#  '2006.11.02',
#  '2006.11.03',
#  '2006.11.04',
#  '2006.11.05',
#  '2006.11.06',
#  '2006.11.07',
#  '2006.11.08',
#  '2006.11.09',
#  '2006.11.10',
#  '2006.11.11',
#  '2006.11.12',
#  '2006.11.13',
#  '2006.11.14',
#  '2006.11.15',
#  '2006.11.16',
#  '2006.11.17',
#  '2006.11.18',
#  '2006.11.19',
#  '2006.11.20',
#  '2006.11.21',
#  '2006.11.22',
#  '2006.11.23',
#  '2006.11.24',
#  '2006.11.25',
#  '2006.11.26',
#  '2006.11.27',
#  '2006.11.28',
#  '2006.11.29',
#  '2006.11.30',
#  '2006.12.01',
#  '2006.12.02',
#  '2006.12.03',
#  '2006.12.04',
#  '2006.12.05',
#  '2006.12.06',
#  '2006.12.07',
#  '2006.12.08',
#  '2006.12.09',
#  '2006.12.10',
#  '2006.12.11',
#  '2006.12.12',
#  '2006.12.13',
#  '2006.12.14',
#  '2006.12.15',
#  '2006.12.16',
#  '2006.12.17',
#  '2006.12.18',
#  '2006.12.19',
#  '2006.12.20',
#  '2006.12.21',
#  '2006.12.22',
#  '2006.12.23',
#  '2006.12.24',
#  '2006.12.25',
#  '2006.12.26',
#  '2006.12.27',
#  '2006.12.28',
#  '2006.12.29',
#  '2006.12.30',
#  '2006.12.31',
#  '2007.01.01',
#  '2007.01.02',
#  '2007.01.03',
#  '2007.01.04',
#  '2007.01.05',
#  '2007.01.06',
#  '2007.01.07',
#  '2007.01.08',
#  '2007.01.09',
#  '2007.01.10',
#  '2007.01.11',
#  '2007.01.12',
#  '2007.01.13',
#  '2007.01.14',
#  '2007.01.15',
#  '2007.01.16',
#  '2007.01.17',
#  '2007.01.18',
#  '2007.01.19',
#  '2007.01.20',
#  '2007.01.21',
#  '2007.01.22',
#  '2007.01.23',
#  '2007.01.24',
#  '2007.01.25',
#  '2007.01.26',
#  '2007.01.27',
#  '2007.01.28',
#  '2007.01.29',
#  '2007.01.30',
#  '2007.01.31',
#  '2007.02.01',
#  '2007.02.02',
#  '2007.02.03',
#  '2007.02.04',
#  '2007.02.05',
#  '2007.02.06',
#  '2007.02.07',
#  '2007.02.08',
#  '2007.02.09',
#  '2007.02.10',
#  '2007.02.11',
#  '2007.02.12',
#  '2007.02.13',
#  '2007.02.14',
#  '2007.02.15',
#  '2007.02.16',
#  '2007.02.17',
#  '2007.02.18',
#  '2007.02.19',
#  '2007.02.20',
#  '2007.02.21',
#  '2007.02.22',
#  '2007.02.23',
#  '2007.02.24',
#  '2007.02.25',
#  '2007.02.26',
#  '2007.02.27',
#  '2007.02.28',
#  '2007.03.01',
#  '2007.03.02',
#  '2007.03.03',
#  '2007.03.04',
#  '2007.03.05',
#  '2007.03.06',
#  '2007.03.07',
#  '2007.03.08',
#  '2007.03.09',
#  '2007.03.10',
#  '2007.03.11',
#  '2007.03.12',
#  '2007.03.13',
#  '2007.03.14',
#  '2007.03.15',
#  '2007.03.16',
#  '2007.03.17',
#  '2007.03.18',
#  '2007.03.19',
#  '2007.03.20',
#  '2007.03.21',
#  '2007.03.22',
#  '2007.03.23',
#  '2007.03.24',
#  '2007.03.25',
#  '2007.03.26',
#  '2007.03.27',
#  '2007.03.28',
#  '2007.03.29',
#  '2007.03.30',
#  '2007.03.31',
#  '2007.04.01',
#  '2007.04.02',
#  '2007.04.03',
#  '2007.04.04',
#  '2007.04.05',
#  '2007.04.06',
#  '2007.04.07',
#  '2007.04.08',
#  '2007.04.09',
#  '2007.04.10',
#  '2007.04.11',
#  '2007.04.12',
#  '2007.04.13',
#  '2007.04.14',
#  '2007.04.15',
#  '2007.04.16',
#  '2007.04.17',
#  '2007.04.18',
#  '2007.04.19',
#  '2007.04.20',
#  '2007.04.21',
#  '2007.04.22',
#  '2007.04.23',
#  '2007.04.24',
#  '2007.04.25',
#  '2007.04.26',
#  '2007.04.27',
#  '2007.04.28',
#  '2007.04.29',
#  '2007.04.30',
#  '2007.05.01',
#  '2007.05.02',
#  '2007.05.03',
#  '2007.05.04',
#  '2007.05.05',
#  '2007.05.06',
#  '2007.05.07',
#  '2007.05.08',
#  '2007.05.09',
#  '2007.05.10',
#  '2007.05.11',
#  '2007.05.12',
#  '2007.05.13',
#  '2007.05.14',
#  '2007.05.15',
#  '2007.05.16',
#  '2007.05.17',
#  '2007.05.18',
#  '2007.05.19',
#  '2007.05.20',
#  '2007.05.21',
#  '2007.05.22',
#  '2007.05.23',
#  '2007.05.24',
#  '2007.05.25',
#  '2007.05.26',
#  '2007.05.27',
#  '2007.05.28',
#  '2007.05.29',
#  '2007.05.30',
#  '2007.05.31',
#  '2007.06.01',
#  '2007.06.02',
#  '2007.06.03',
#  '2007.06.04',
#  '2007.06.05',
#  '2007.06.06',
#  '2007.06.07',
#  '2007.06.08',
#  '2007.06.09',
#  '2007.06.10',
#  '2007.06.11',
#  '2007.06.12',
#  '2007.06.13',
#  '2007.06.14',
#  '2007.06.15',
#  '2007.06.16',
#  '2007.06.17',
#  '2007.06.18',
#  '2007.06.19',
#  '2007.06.20',
#  '2007.06.21',
#  '2007.06.22',
#  '2007.06.23',
#  '2007.06.24',
#  '2007.06.25',
#  '2007.06.26',
#  '2007.06.27',
#  '2007.06.28',
#  '2007.06.29',
#  '2007.06.30',
#  '2007.07.01',
#  '2007.07.02',
#  '2007.07.03',
#  '2007.07.04',
#  '2007.07.05',
#  '2007.07.06',
#  '2007.07.07',
#  '2007.07.08',
#  '2007.07.09',
#  '2007.07.10',
#  '2007.07.11',
#  '2007.07.12',
#  '2007.07.13',
#  '2007.07.14',
#  '2007.07.15',
#  '2007.07.16',
#  '2007.07.17',
#  '2007.07.18',
#  '2007.07.19',
#  '2007.07.20',
#  '2007.07.21',
#  '2007.07.22',
#  '2007.07.23',
#  '2007.07.24',
#  '2007.07.25',
#  '2007.07.26',
#  '2007.07.27',
#  '2007.07.28',
#  '2007.07.29',
#  '2007.07.30',
#  '2007.07.31',
#  '2007.08.01',
#  '2007.08.02',
#  '2007.08.03',
#  '2007.08.04',
#  '2007.08.05',
#  '2007.08.06',
#  '2007.08.07',
#  '2007.08.08',
#  '2007.08.09',
#  '2007.08.10',
#  '2007.08.11',
#  '2007.08.12',
#  '2007.08.13',
#  '2007.08.14',
#  '2007.08.15',
#  '2007.08.16',
#  '2007.08.17',
#  '2007.08.18',
#  '2007.08.19',
#  '2007.08.20',
#  '2007.08.21',
#  '2007.08.22',
#  '2007.08.23',
#  '2007.08.24',
#  '2007.08.25',
#  '2007.08.26',
#  '2007.08.27',
#  '2007.08.28',
#  '2007.08.29',
#  '2007.08.30',
#  '2007.08.31',
#  '2007.09.01',
#  '2007.09.02',
#  '2007.09.03',
#  '2007.09.04',
#  '2007.09.05',
#  '2007.09.06',
#  '2007.09.07',
#  '2007.09.08',
#  '2007.09.09',
#  '2007.09.10',
#  '2007.09.11',
#  '2007.09.12',
#  '2007.09.13',
#  '2007.09.14',
#  '2007.09.15',
#  '2007.09.16',
#  '2007.09.17',
#  '2007.09.18',
#  '2007.09.19',
#  '2007.09.20',
#  '2007.09.21',
#  '2007.09.22',
#  '2007.09.23',
#  '2007.09.24',
#  '2007.09.25',
#  '2007.09.26',
#  '2007.09.27',
#  '2007.09.28',
#  '2007.09.29',
#  '2007.09.30',
#  '2007.10.01',
#  '2007.10.02',
#  '2007.10.03',
#  '2007.10.04',
#  '2007.10.05',
#  '2007.10.06',
#  '2007.10.07',
#  '2007.10.08',
#  '2007.10.09',
#  '2007.10.10',
#  '2007.10.11',
#  '2007.10.12',
#  '2007.10.13',
#  '2007.10.14',
#  '2007.10.15',
#  '2007.10.16',
#  '2007.10.17',
#  '2007.10.18',
#  '2007.10.19',
#  '2007.10.20',
#  '2007.10.21',
#  '2007.10.22',
#  '2007.10.23',
#  '2007.10.24',
#  '2007.10.25',
#  '2007.10.26',
#  '2007.10.27',
#  '2007.10.28',
#  '2007.10.29',
#  '2007.10.30',
#  '2007.10.31',
#  '2007.11.01',
#  '2007.11.02',
#  '2007.11.03',
#  '2007.11.04',
#  '2007.11.05',
#  '2007.11.06',
#  '2007.11.07',
#  '2007.11.08',
#  '2007.11.09',
#  '2007.11.10',
#  '2007.11.11',
#  '2007.11.12',
#  '2007.11.13',
#  '2007.11.14',
#  '2007.11.15',
#  '2007.11.16',
#  '2007.11.17',
#  '2007.11.18',
#  '2007.11.19',
#  '2007.11.20',
#  '2007.11.21',
#  '2007.11.22',
#  '2007.11.23',
#  '2007.11.24',
#  '2007.11.25',
#  '2007.11.26',
#  '2007.11.27',
#  '2007.11.28',
#  '2007.11.29',
#  '2007.11.30',
#  '2007.12.01',
#  '2007.12.02',
#  '2007.12.03',
#  '2007.12.04',
#  '2007.12.05',
#  '2007.12.06',
#  '2007.12.07',
#  '2007.12.08',
#  '2007.12.09',
#  '2007.12.10',
#  '2007.12.11',
#  '2007.12.12',
#  '2007.12.13',
#  '2007.12.14',
#  '2007.12.15',
#  '2007.12.16',
#  '2007.12.17',
#  '2007.12.18',
#  '2007.12.19',
#  '2007.12.20',
#  '2007.12.21',
#  '2007.12.22',
#  '2007.12.23',
#  '2007.12.24',
#  '2007.12.25',
#  '2007.12.26',
#  ...]

# %%
datels = datels[::-1]
dfno = pd.DataFrame([datels], index=['date'])
dfno = dfno.T
dfno
# Out:
#             date
# 0     2017.12.31
# 1     2017.12.30
# 2     2017.12.29
# 3     2017.12.28
# 4     2017.12.27
# ...          ...
# 4653  2005.04.05
# 4654  2005.04.04
# 4655  2005.04.03
# 4656  2005.04.02
# 4657  2005.04.01
#
# [4658 rows x 1 columns]

# %%
k = pd.merge(dfno, Call_rates, how='left')
k
# Out:
#             date callrate
# 0     2017.12.31      NaN
# 1     2017.12.30      NaN
# 2     2017.12.29     1.52
# 3     2017.12.28     1.58
# 4     2017.12.27     1.55
# ...          ...      ...
# 4653  2005.04.05      NaN
# 4654  2005.04.04     3.23
# 4655  2005.04.03      NaN
# 4656  2005.04.02      NaN
# 4657  2005.04.01     3.24
#
# [4658 rows x 2 columns]

# %%
Call = k.fillna(method='bfill')

# %%
Call
# Out:
#             date callrate
# 0     2017.12.31     1.52
# 1     2017.12.30     1.52
# 2     2017.12.29     1.52
# 3     2017.12.28     1.58
# 4     2017.12.27     1.55
# ...          ...      ...
# 4653  2005.04.05     3.23
# 4654  2005.04.04     3.23
# 4655  2005.04.03     3.24
# 4656  2005.04.02     3.24
# 4657  2005.04.01     3.24
#
# [4658 rows x 2 columns]

# %%
int(Call.loc[0]['date'].strip())
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-237-123f0c60b2d9> in <module>()
# ----> 1 int(Call.loc[0]['date'].strip())
#
# ValueError: invalid literal for int() with base 10: '2017.12.31'

# %%
len(Call)
# Out:
# 4658

# %%
import datetime
datetime.strptime('2015.02.05')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-242-f3f12437167f> in <module>()
#       1 import datetime
# ----> 2 datetime.strptime('2015.02.05')
#
# AttributeError: module 'datetime' has no attribute 'strptime'

# %%
from datetime import datetime
# Out:
# <class 'str'>
# <class 'datetime.datetime'>
# 2018-09-15 00:00:00

# %%
Call_A = Call.loc[:][:][:-30]
Call_B = Call.loc[:][:][30:].rename({'date':'한달전 date', 'callrate':'한달전 callrate'}, axis='columns').reset_index(drop=True)

# %%
len(Call_A), len(Call_B)
# Out:
# (4628, 4628)

# %%
CALLRATE = pd.merge(Call_A, Call_B, left_index=True, right_index=True)
CALLRATE['한달전 date'][0], CALLRATE['한달전 callrate'][0] = CALLRATE['한달전 date'][1], CALLRATE['한달전 callrate'][1]# 12/31일이 그냥 슬라이싱 한거로 가져오면 12/01을 가져오게 되기 때문에 마지막 날만 맞춰줌... 근데 숫자만 31일 전으로 돌리는것 같아서 뭔가 잘못된것같네...다시해야겠다

CALLRATE
# Out:
#             date callrate    한달전 date 한달전 callrate
# 0     2017.12.31     1.52  2017.11.30         1.24
# 1     2017.12.30     1.52  2017.11.30         1.24
# 2     2017.12.29     1.52  2017.11.29         1.53
# 3     2017.12.28     1.58  2017.11.28         1.26
# 4     2017.12.27     1.55  2017.11.27         1.26
# ...          ...      ...         ...          ...
# 4623  2005.05.05     3.27  2005.04.05         3.23
# 4624  2005.05.04     3.27  2005.04.04         3.23
# 4625  2005.05.03     3.21  2005.04.03         3.24
# 4626  2005.05.02     3.30  2005.04.02         3.24
# 4627  2005.05.01     3.23  2005.04.01         3.24
#
# [4628 rows x 4 columns]

# %%
from datetime import date

day = date(2015, 3, 28)
time = day - pd.DateOffset(months=1)
print(time.date())
# Out:
# 2015-02-28

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-21-54e971921292> in <module>()
#       1 for i in range(len(Call_rates.index)):
#       2   time = Call_rates.index[i]
# ----> 3   time2 = Call_rates.index[i] - pd.DateOffset(months = 1)
#       4
#       5   if time.year >= 2005:
#
# pandas/_libs/tslibs/offsets.pyx in pandas._libs.tslibs.offsets.BaseOffset.__rsub__()
#
# pandas/_libs/tslibs/offsets.pyx in pandas._libs.tslibs.offsets._BaseOffset.__add__()
#
# /usr/local/lib/python3.6/dist-packages/pandas/tseries/offsets.py in wrapper(self, other)
#     109                 other = other.tz_localize(None)
#     110
# --> 111             result = func(self, other)
#     112
#     113             if self._adjust_dst:
#
# /usr/local/lib/python3.6/dist-packages/pandas/tseries/offsets.py in apply(self, other)
#     284             else:
#     285                 for i in range(-self.n):
# --> 286                     other = other - self._offset
#     287
#     288             if tzinfo is not None and self._use_relativedelta:
#
# TypeError: unsupported operand type(s) for -: 'str' and 'relativedelta'
